# %% [markdown]
# <h1>Funciones</h1>

# %% [markdown]
# Una función es un bloque de código reutilizable que realiza operaciones especificadas en la función. <br>
# Permiten dividir las tareas y reutilizar el código en distintos programas.<br>
#
#
# Existen dos tipos de funciones :
#
#
# * <b>Funciones predefinidas</b>
# * <b>Funciones definidas por el usuario</b>

# %% [markdown]
# <h2>¿Qué es una función?</h2>

# %% [markdown]
# Puede definir funciones para proporcionar la funcionalidad requerida. <br>
# Aquí hay reglas simples para definir una función en Python: <br>
#
# * Los bloques de funciones comienzan con <code>def</code> seguido de la función <code>name</code> y paréntesis <code>()</code>.
# * Hay parámetros de entrada o argumentos que deben colocarse dentro de estos paréntesis.
# * También puede definir parámetros dentro de estos paréntesis.
# * Hay un cuerpo dentro de cada función que comienza con dos puntos (<code>:</code>) y tiene indentado.
# * También se puede colocar documentación ante el cuerpo de la función.
# * La declaración <code>return</code> sale de una función y, opcionalmente, devuelve un valor.

# %% [markdown]
# <h2>Documentación del codigo</h2>

# %% [markdown]
# Si puede documentar el codigo en 3 formas:
# * con el carácter numeral (#)
# * con triple comillas simples (''')
# * triple comillas doble(""")
#
# #Comentario de una sola línea <br>
# <br>
# '''<br>
# Al utilizar triple comillas dobles podremos<br>
# añadir saltos de línea a nuestro comentario.<br>
# <br>
# Al utilizar comillas simples podemos utilizar comillas "dobles".<br>
# '''<br>
# <br>
# """<br>
# Al utilizar triple comillas dobles podremos<br>
# añadir saltos de línea a nuestro comentario.<br>
# <br>
# Al utilizar comillas dobles podemos utilizar comillas 'simples'.<br>
# """

# %% [markdown]
# <h2>Ejemplo función</h2>

# %% [markdown]
# Un ejemplo de una función que se suma dos valores: <code>valore_a</code> y <code>valore_b</code> y imprime el resultado:

# %%
def suma(valore_a, valore_b):
    
    """
    función que suma el parámetro valore_a al parámetro valore_b 
    """
    
    resultado = valore_a + valore_b
    print(valore_a, "+", valore_b, " = ", resultado)
    return(resultado)


suma(1,2)
# Out:
# 1 + 2  =  3
# 3

# %% [markdown]
# La siguiente figura ilustra la terminología:

# %% [markdown]
# <img src="......" align="center" />

# %% [markdown]
# Podemos obtener ayuda (documentación) sobre una función :

# %%
help(suma)
# Out:
# Help on function suma in module __main__:
#
# suma(valore_a, valore_b)
#     función que suma el parámetro valore_a al parámetro valore_b

# %% [markdown]
# Podemos llamar a la función:

# %%
suma(1,2)
# Out:
# 1 + 2  =  3
# 3

# %% [markdown]
# Si llamamos a la función con nuevos parámetros obtendremos un nuevo resultado:

# %%
suma(2,3)
# Out:
# 2 + 3  =  5
# 5

# %% [markdown]
# Podemos crear diferentes funciones. <br>
# Por ejemplo, podemos crear una función que multiplique dos números. <br>
# Los números estarán representados por las variables <code>valore_a</code> y <code>valore_b</code>:

# %%
def multiplication (valore_a, valore_b):
    resultado = valore_a * valore_b
    return(resultado)
    print('Este método print será ignorado porque está después de la declaración return')
    
resultado_multiplication = multiplication(12,2)
print(resultado_multiplication)
# Out:
# 24

# %% [markdown]
# La misma función puede utilizarse para distintos tipos de datos. Por ejemplo, podemos multiplicar dos números enteros:

# %%
multiplication(2, 3)
# Out:
# 6

# %% [markdown]
# Dos números con decimales:

# %%
multiplication(10.0, 3.14)
# Out:
# 31.400000000000002

# %% [markdown]
# Incluso podemos replicar una string multiplicándola por un número entero:

# %%
multiplication(2, "Tiziano ")
# Out:
# 'Tiziano Tiziano '

# %% [markdown]
# <hr>
# <h2>Variables</h2>

# %% [markdown]
# <ul>
#     <li>La entrada de una función se denomina <code>parámetro formal</code></li>
#     <li>Una variable que se declara dentro de una función se denomina <code>variable local</code>. El parámetro sólo existe dentro de la función (es decir, el punto donde empieza y termina la función).</li>
#     <li>Una variable que se declara fuera de la definición de una función es una <code>variable global</code>, y su valor es accesible y modificable en todo el programa. </li>
# </ul>

# %%
# variable global 
variable_a = 2

def cuadrado_suma_y_division(variable_b):
    # variable local
    variable_c = 3
    resultado = ((variable_a * variable_a)+variable_b)/variable_c
    print(f"Resultado: (({variable_a} * {variable_a})+{variable_b})/{variable_c} = {resultado}" ) 
    return(resultado)

cuadrado_suma_y_division(5)

print (f"Variable_a={variable_a}")
#print (f"Variable_b={variable_b}")
#print (f"Variable_c={variable_c}")
# Out:
# Resultado: ((2 * 2)+5)/3 = 3.0
# Variable_a=2

# %% [markdown]
# <div class="alert alert-success alertsuccess" style="margin-top: 20px">
# Notar que si descomentamos la impresión de <code>variable_b</code> o <code>variable_c</code> tendremos un error, eso porque esas variables solo están disponibles dentro de la función
# </div>

# %% [markdown]
# <hr>
# <h2><code>return</code></h2>

# %% [markdown]
# Si no hay <code>return</code>, la función devuelve <code>null</code> (nada). Las dos funciones siguientes son equivalentes:

# %%
def función_no_return():
    print('Tiziano')
    
def función_con_return():
    print('Tiziano')
    return(None)

# %%
función_no_return()
# Out:
# Tiziano

# %%
función_con_return()
# Out:
# Tiziano

# %% [markdown]
# La impresión de la función tras una llamada revela que una **None** es la sentencia de retorno por defecto:

# %%
# See what functions returns are

print(función_no_return())
print(función_con_return())
# Out:
# Tiziano
# None
# Tiziano
# None

# %% [markdown]
# Create a function <code>con</code> that  concatenates two strings using the addition operation:

# %% [markdown]
# <h2>Las funciones simplifican las cosas</h2>

# %% [markdown]
# Considera las dos líneas de código en <b>Bloque 1</b> y <b>Bloque 2</b>: el procedimiento para cada bloque es idéntico.<br>
# Lo único que difiere son los nombres y valores de las variables.

# %% [markdown]
# <h3>Bloque 1:</h3>

# %%
a1 = 4
b1 = 5
c1 = a1 + b1 + 2 * a1 * b1 - 1
if(c1 < 0):
    c1 = 0 
else:
    c1 = 5
c1
# Out:
# 5

# %% [markdown]
# <h3>Bloque 2:</h3>

# %%
a2 = 0
b2 = 0
c2 = a2 + b2 + 2 * a2 * b2 - 1
if(c2 < 0):
    c2 = 0 
else:
    c2 = 5
c2
# Out:
# 0

# %% [markdown]
# Podemos sustituir las líneas de código por una función. <br>
# Una función combina muchas instrucciones en una sola línea de código. <br>
# Una vez definida una función, puede utilizarse repetidamente. <br>
# Puedes invocar la misma función muchas veces en tu programa. <br>
# Puede guardar la función y utilizarla en otro programa o utilizar la función de otra persona. <br>
# Las líneas de código en el código <b>Bloque 1</b> y código <b>Bloque 2</b> puede sustituirse por la siguiente función:

# %%
def equación(a,b):
    c = a + b + 2 * a * b - 1
    if(c < 0):
        c = 0 
    else:
        c = 5
    return(c)

# %% [markdown]
# Esta función toma dos entradas, <code>a</code> y <code>b</code>, y luego aplica varias operaciones para devolver <code>c</code>.<br>
# Simplemente definimos la función, sustituimos las instrucciones por la función e introducimos los nuevos valores de <code>a1</code>, <code>b1</code>, <code>a2</code> y <code>b2</code>  como entradas.<br>
# El proceso completo se muestra en la figura:

# %% [markdown]
# <img src="......" align="center" />

# %% [markdown]
# Código **Bloques 1** y **Bloque 2** pueden ser ahora sustituido por el código **Bloque 3** y el código **Bloque 4**.

# %% [markdown]
# <h3>Bloque 3:</h3>

# %%
a1 = 4
b1 = 5
c1 = equación(a1, b1)
c1
# Out:
# 5

# %% [markdown]
# <h3>Bloque 4:</h3>

# %%
a2 = 0
b2 = 0
c2 = equación(a2, b2)
c2
# Out:
# 0

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>Funciones built-in (incorporadas)</h2>

# %% [markdown]
# El intérprete de Python tiene una serie de funciones y tipos incluidos en él que están siempre disponibles. Están listados aquí en orden alfabético.
#
# **A**
# abs()
# aiter()
# all()
# anext()
# any()
# ascii()
#
# **B**
# bin()
# bool()
# breakpoint()
# bytearray()
# bytes()
#
# **C**
# callable()
# chr()
# classmethod()
# compile()
# complex()
#
# **D**
# delattr()
# dict()
# dir()
# divmod()
#
# **E**
# enumerate()
# eval()
# exec()
#
# **F**
# filter()
# float()
# format()
# frozenset()
#
# **G**
# getattr()
# globals()
#
# **H**
# hasattr()
# hash()
# help()
# hex()
#
# **I**
# id()
# input()
# int()
# isinstance()
# issubclass()
# iter()
#
# **L**
# len()
# list()
# locals()
#
# **M**
# map()
# max()
# memoryview()
# min()
#
# **N**
# next()
#
# **O**
# object()
# oct()
# open()
# ord()
#
# **P**
# pow()
# print()
# property()
#
# **R**
# range()
# repr()
# reversed()
# round()
#
# **S**
# set()
# setattr()
# slice()
# sorted()
# staticmethod()
# str()
# sum()
# super()
#
# **T**
# tuple()
# type()
#
# **V**
# vars()
#
# **Z**
# zip()

# %% [markdown]
# La lista completa puede consultarse en: https://docs.python.org/es/3/library/functions.html

# %% [markdown]
# <hr>
# <h2>Usar <code>if</code>/<code>else</code> y bucles en funciones</h2>

# %% [markdown]
# La función <code>return()</code> es particularmente útil si tienes alguna declaración <code>if</code> en la función, cuando quieres que tu salida dependa de alguna condición:

# %%
def nombre_y_rol(nombre, es_alumno):
    if es_alumno == True:
        return "Profesor "+ nombre
    else:
        return "Alumno" + nombre
x = nombre_y_rol("Tiziano", True)
print(x)
# Out:
# Profesor Tiziano

# %% [markdown]
# Podemos utilizar un bucle en una función. <br>
# Por ejemplo, podemos <code>print()</code> cada elemento de una lista:

# %%
def imprimirLista(lista):
    for elemento in lista:
        print(elemento)

# %%
imprimirLista(['1', 1, 'Hola', "Felipe", True])
# Out:
# 1
# 1
# Hola
# Felipe
# True

# %% [markdown]
# <h2 id="if">Comparación de <code>string</code> en funciones</h2>

# %% [markdown]
# Los operadores relacionales comparan los valores Unicode de los caracteres de las <code>string</code> desde el índice 0 hasta el final de la <code>string</code><br>
# A continuación, devuelve un valor booleano según el operador utilizado.

# %%
def compara_string(testo, testo_da_buscar):
    if testo_da_buscar in testo:
        return 'Testo da buscar encontrado'
    else:
        return 'Testo da buscar no encontrado'

compara_string("Tiziano Borrelli","Tiziano")
# Out:
# 'Testo da buscar encontrado'

# %% [markdown]
# **Cuenta la frecuencia de las palabras que aparecen en una <code>string</code> utilizando un diccionario.**.
#
# Supongamos que tenemos una <code>string</code> y <code>palabras</code> y tenemos que encontrar el recuento de ocurrencia de esta <code>testo_da_buscar</code> en la string utilizando python. <br>
# Esto es lo que vamos a hacer en esta sección, contar el número de <code>testo_da_buscar</code> en una <code>string</code> dada e imprimirlo. <br>
# 1. Lo primero que haremos será definir una función
# 2. Crear una lista que estará vacía inicialmente.
# 3. Convertir la <code>string</code> en una lista. Python string tiene un método <code>split()</code>. Toma una <code>string</code> y algún separador para devolver una lista.
# 4. Diccionario vacío.
# 5. Bucle <code>for</code> para iterar las palabras y el valor contará la frecuencia de cada palabra en la <code>string</code> y las almacenará en el diccionario.
# 6. Print del diccionario.

# %%
#1 Lo primero que haremos será definir una función
def conta_palabras(texto):
    
    #2 Crear una lista que estará vacía inicialmente.
    palabras = []
    
    #3 Convertir la string en una lista.
    palabras = texto.split() # or string.lower().split()
    
    #4 Diccionario vacío.
    diccionario = {}
    
    #5 Bucle <code>for</code> para iterar las palabras
    for clave in palabras:
        diccionario[clave] = palabras.count(clave)
        
    #6 Print del diccionario.
    print("La frecuencia de las palabras es:",diccionario)
    
# Test
conta_palabras("Con mi burrito sabanero, voy camino de Belén " \
               "Con mi burrito sabanero, voy camino de Belén " \
               "Si me ven, si me ven " \
               "Voy camino de Belén ")
# Out:
# La frecuencia de las palabras es: {'Con': 2, 'mi': 2, 'burrito': 2, 'sabanero,': 2, 'voy': 2, 'camino': 3, 'de': 3, 'Belén': 3, 'Si': 1, 'me': 2, 'ven,': 1, 'si': 1, 'ven': 1, 'Voy': 1}

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>Valores por defecto en funciones</h2>

# %% [markdown]
# Se puede establecer un valor predeterminado para los argumentos en su función. <br>
# Por ejemplo, en el <code>saludo()</code> saludamos al usuario utilizando el parámetro <code>hora</code>

# %%
def saludo(hora=8): 
    if(hora < 13):
        print("Buenos dias")
    elif (hora < 18):
        print("Buenas tardes")
    else:
        print("Buenas noche")

# %%
saludo()
saludo(18)
# Out:
# Buenos dias
# Buenas noche

# %% [markdown]
# <hr>

# %% [markdown]
# <h2>Variables globales</h2>

# %% [markdown]
# Hasta ahora, hemos estado creando variables dentro de las funciones, pero no hemos discutido las variables fuera de la función. <br>
# Estas se llaman <code>variables globales</code>. <br>
# Intentemos ver qué <code>imprimir_1</code> devuelve:

# %%
global_nombre = "Tiziano"
def imprimir_1(nombre):
    internal_nombre = nombre
    print("Hola",nombre)
    
imprimir_1(global_nombre)
# intenta ejecutar el siguiente código
imprimir_1(internal_var1)
# Out:
# Hola Tiziano
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[112], line 8
#       6 imprimir_1(global_nombre)
#       7 # intenta ejecutar el siguiente código
# ----> 8 imprimir_1(internal_var1)
#
# NameError: name 'internal_var1' is not defined

# %% [markdown]
# Tenemos un <b>NameError</b>: <code>name 'internal_var' is not defined</code>. <br>
# ¿Por qué?<br>
# Es porque todas las variables que creamos en la función es una <b>variable local</b>, lo que significa que la asignación de la variable no persiste fuera de la función.<br>
# Pero hay una forma de crear <b>variables globales</b> desde dentro de una función como sigue:

# %%
global_nombre = "Tiziano"
def imprimir_1(nombre):
    global internal_global_nombre
    internal_global_nombre = "Jose"
    print("Hola",nombre)
    
imprimir_1(global_nombre)
# intenta ejecutar el siguiente código
imprimir_1(internal_global_nombre)
# Out:
# Hola Tiziano
# Hola Jose

# %% [markdown]
# <hr>
# <h2><code>*args</code> y <code>**kwargs</code></h2>

# %% [markdown]
# <h3><code>*args</code></h3>

# %% [markdown]
# Gracias a los <code>*args</code> en Python, podemos definir funciones cuyo número de argumentos es variable. <br>
# Es decir, podemos definir funciones genéricas que no aceptan un número determinado de parámetros, sino que se “adaptan” al número de argumentos con los que son llamados. <br>
# De hecho, el <code>*args</code> viene de arguments en Inglés, o argumentos. <br>
# Haciendo uso de <code>*args</code> en la declaración de la función podemos hacer que el número de parámetros que acepte sea variable.

# %%
def imprimir_todos_parametro(*args): # Todos los argumentos se 'empaquetan' en args que puede tratarse como una tupla.
    print("Nº de parámetros:", len(args))
    for parámetro in args:
        print(parámetro)

#printAll con 3 argumentos
imprimir_todos_parametro('Jose','Maria','Sandra')
#printAll con 4 argumentos
imprimir_todos_parametro('Jose','Tiziano','Maria','Sandra')
# Out:
# Nº de parámetros: 3
# Jose
# Maria
# Sandra
# Nº de parámetros: 4
# Jose
# Tiziano
# Maria
# Sandra

# %% [markdown]
# Antes de nada, el uso del nombre <code>*args</code> es totalmente arbitrario, por lo que podrías haberlo llamado como quisieras. <br>
# Es una mera convención entre los usuarios de Python y resulta frecuente darle ese nombre. <br>
# <b>Lo que si es un requisito, es usar * junto al nombre.</b><br>
# <br>
# En el ejemplo anterior hemos visto como <code>*args</code> puede ser iterado, ya que en realidad es una tupla. <br>
# Por lo tanto iterando la tupla podemos acceder a todos los argumentos de entrada

# %% [markdown]
# <h3><code>**kwargs</code></h3>

# %% [markdown]
# Al igual que en <code>*args</code>, en <code>\**kwargs</code> el nombre es una mera convención entre los usuarios de Python.<br>
# Puedes usar cualquier otro nombre siempre y cuando respetes el <b>**</b>.

# %%
def imprimir_todos_parametro(**kwargs):
    for clave, valor in kwargs.items():
        print(clave, "=", valor)

imprimir_todos_parametro(Nombre='Tiziano', Apellido='Borrelli', Nacionalidad = 'Italiana')
# Out:
# Nombre = Tiziano
# Apellido = Borrelli
# Nacionalidad = Italiana

# %% [markdown]
# <hr>
# <h2>Cuestionario sobre las funciones</h2>

# %% [markdown]
# Crea una función que divida el primer parámetro por el segundo:

# %%
# Escribe tu código y pulsa Shift+Enter para ejecutar

# %% [markdown]
# <details><summary>Haz doble clic <b>aquí</b> para la solución.</summary>
# <b>
#
# ```python
# def división(a, b):
#     return(a/b)
#
# ```
#
# </b>
# </details>

# %% [markdown]
# <hr>

# %% [markdown]
# Escribe una función para imprimir el recuento total de la palabra `camino` en la <code>string</code>:<br>
# "Con mi burrito sabanero, voy camino de Belén, Con mi burrito sabanero, voy camino de Belén, Si me ven, si me ven, Voy camino de Belén"

# %%
# Escribe tu código y pulsa Shift+Enter para ejecutar

# %% [markdown]
# <details><summary>Haz doble clic <b>aquí</b> para la solución.</summary>
# <b>
#
#
# ```python
# def conta_palabras(texto,palabra_a_encontrar):
#     palabras = []
#     palabras = texto.split() # or string.lower().split()
#     diccionario = {}
#     for palabra in palabras:
#         if(palabra == palabra_a_encontrar):
#             diccionario[palabra] = palabras.count(palabra)
#     print("Número de palabras:",diccionario)
#
# #step6: Call function and pass string in it
# conta_palabras("Con mi burrito sabanero, voy camino de Belén, Con mi burrito sabanero, voy camino de Belén, Si me ven, si me ven, Voy camino de Belén","camino")
#
# ```
#
# </b>
# </details>
